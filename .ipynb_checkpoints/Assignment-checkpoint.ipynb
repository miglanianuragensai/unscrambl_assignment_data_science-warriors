# %% [markdown]
# This is the notebook for an assignment given to me by an manager and it contains different algorithms and techniques to explore and thus practice with the data..
#
# You could download the data from:- https://data.ok.gov/sites/default/files/res_purchase_card_%28pcard%29_fiscal_year_2014_3pcd-aiuu.csv
# or download it from git itself. :) Happy Learning...

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
from pandas import Series
import csv
import numpy as np
import time as tm
import sklearn as sk
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.manifold import TSNE
from scipy.spatial.distance import cdist, pdist
from sklearn.cluster import KMeans
from matplotlib import style

from mpl_toolkits.mplot3d import Axes3D
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# About the dataset:
#     Each row in the dataset refers to one credit card purchase by a cardholder. Each cardholder belongs to an agency. Each transaction has information about the amount, date, merchant and merchant category, as well as description of the expense.

# %% [markdown]
# Task A:
#     Read and parse the data into a manageable structure.  Output the total number of rows read and the number of invalid rows, if any.

# %%
#Reading the csv file
test = pd.read_csv('/Users/warriors/output1',sep = ",")

# %% [markdown]
# In the below steps, the no of rows are displayed and the rows with NaN's are deleted to make life easier, we would have taken another approach if there were a lot of NaN's but fortunately only the last row comprises of it.

# %%
test
# Out:
#         Year-Month  Agency Number                Agency Name  \
# 0           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 1           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 2           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 3           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 4           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 5           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 6           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 7           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 8           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 9           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 10          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 11          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 12          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 13          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# ...

# %%
test.shape
# Out:
# (274999, 11)

# %%
test.last
# Out:
# <bound method DataFrame.last of         Year-Month  Agency Number                Agency Name  \
# 0           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 1           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 2           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 3           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 4           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 5           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 6           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 7           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 8           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 9           201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 10          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 11          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 12          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# 13          201307         1000.0  OKLAHOMA STATE UNIVERSITY
# ...

# %% [markdown]
# Drop the rows with na and again look at the values of the shape i.e. rows*columns of the dataframe, what we notice
# is one less value than before

# %%
num_of_rows = test.shape[0]
num_of_rows
# Out:
# 274999

# %%
test.isnull().sum()
# Out:
# Year-Month                      0
# Agency Number                   1
# Agency Name                     1
# Cardholder Last Name            1
# Cardholder First Initial        1
# Description                     1
# Amount                          1
# Vendor                          1
# Transaction Date                1
# Posted Date                     1
# Merchant Category Code (MCC)    1
# dtype: int64

# %%
test = test[-test.isnull().any(axis=1)]

# %%
test.shape
# Out:
# (274998, 11)

# %%
test.dtypes
# Out:
# Year-Month                        int64
# Agency Number                   float64
# Agency Name                      object
# Cardholder Last Name             object
# Cardholder First Initial         object
# Description                      object
# Amount                          float64
# Vendor                           object
# Transaction Date                 object
# Posted Date                      object
# Merchant Category Code (MCC)     object
# dtype: object

# %%
test.columns
test.columns = [x.lower() for x in test.columns]
test.columns
# Out:
# Index([u'year-month', u'agency number', u'agency name',
#        u'cardholder last name', u'cardholder first initial', u'description',
#        u'amount', u'vendor', u'transaction date', u'posted date',
#        u'merchant category code (mcc)'],
#       dtype='object')

# %% [markdown]
# b.Compute and visualize/print the following statistics on the data : the overall distribution of the amounts as a histogram, the top-k most popular vendors by number of transactions, the top-k highest categories by sum of amounts.
#    Produce the results for k=5. For the histogram, you can decide on the appropriate number and size of the bins.

# %% [markdown]
# Now some formatting of the data needs to be done, such as changing the dates and time for the same and creating some extra columns

# %%
test["amount"] = np.round(test["amount"])
print np.max(test["amount"])
print np.min(test["amount"])
# Out:
# 1903858.0
# -38507.0

# %%
aa = np.floor(np.array(test['amount']))
fig = plt.figure()
toto = fig.add_subplot(1,1,1)
toto.hist(aa,color="y",alpha = 0.5,bins="auto",histtype='step')
toto.set_xlabel("amount")
toto.set_ylabel("counts")

# %%
test["amount"].groupby(test["amount"]).value_counts().nlargest(100)
# Out:
# amount  amount
# 20.0    20.0      8506
# 25.0    25.0      5273
# 30.0    30.0      3056
# 10.0    10.0      2235
# 12.0    12.0      2184
# 15.0    15.0      2182
# 50.0    50.0      2084
# 40.0    40.0      1935
# 5.0     5.0       1927
# 8.0     8.0       1922
# 9.0     9.0       1893
# 13.0    13.0      1851
# 6.0     6.0       1816
# 34.0    34.0      1729
# 18.0    18.0      1701
# 14.0    14.0      1689
# 29.0    29.0      1683
# 16.0    16.0      1658
# 17.0    17.0      1643
# 11.0    11.0      1642
# 24.0    24.0      1642
# 60.0    60.0      1627
# 7.0     7.0       1618
# 35.0    35.0      1612
# 100.0   100.0     1583
# 19.0    19.0      1565
# 22.0    22.0      1539
# 77.0    77.0      1534
# 28.0    28.0      1493
# 4.0     4.0       1434
#                   ...
# 200.0   200.0      849
# 68.0    68.0       837
# 69.0    69.0       832
# 3.0     3.0        827
# 85.0    85.0       792
# 62.0    62.0       788
# 59.0    59.0       786
# 64.0    64.0       771
# ...

# %% [markdown]
# as you could see a large population is gathered in between +1000 to -300, lets create the bin boundaries around that and have a look

# %%
((-300 < aa) & (aa < 1000)).sum()
# Out:
# 252160

# %%
amount_bins = []
counter = 0
amount_bins = []
while counter < 1000:
    amount_bins.append(-300 + (counter*10))
    counter += 1
fig = plt.figure()
plt.xlim(-300,1000)
toto = fig.add_subplot(1,1,1)
toto.hist(aa,color="b",alpha = 1,bins=amount_bins)
toto.set_xlabel("amount")
toto.set_ylabel("counts")

# %%
test.dtypes
test["vendor"].groupby(test["vendor"]).value_counts().nlargest(5)
# Out:
# vendor                vendor
# STAPLES               STAPLES                 9391
# WW GRAINGER           WW GRAINGER             7695
# AMAZON MKTPLACE PMTS  AMAZON MKTPLACE PMTS    7524
# Amazon.com            Amazon.com              6515
# LOWES #00241          LOWES #00241            3010
# Name: vendor, dtype: int64

# %%
test["amount"].groupby(test["vendor"]).sum().nlargest(5)
# Out:
# vendor
# PAYMENT ADJUSTMENT       4057133.0
# WW GRAINGER              3209398.0
# EMC CORPORATION          1918547.0
# DMI  DELL K-12/GOVT      1529063.0
# DMI  DELL HIGHER EDUC    1528204.0
# Name: amount, dtype: float64

# %% [markdown]
# c. Create a clustering model that clusters cardholders based on the frequency of credit card usage and spend and number of unique merchants. Identify/Name the clusters and provide relevant metrics that reflect the quality of the clustering.

# %%
test["amount"].groupby(test["amount"]).value_counts().nlargest(100)
# Out:
# amount  amount
# 20.0    20.0      8506
# 25.0    25.0      5273
# 30.0    30.0      3056
# 10.0    10.0      2235
# 12.0    12.0      2184
# 15.0    15.0      2182
# 50.0    50.0      2084
# 40.0    40.0      1935
# 5.0     5.0       1927
# 8.0     8.0       1922
# 9.0     9.0       1893
# 13.0    13.0      1851
# 6.0     6.0       1816
# 34.0    34.0      1729
# 18.0    18.0      1701
# 14.0    14.0      1689
# 29.0    29.0      1683
# 16.0    16.0      1658
# 17.0    17.0      1643
# 11.0    11.0      1642
# 24.0    24.0      1642
# 60.0    60.0      1627
# 7.0     7.0       1618
# 35.0    35.0      1612
# 100.0   100.0     1583
# 19.0    19.0      1565
# 22.0    22.0      1539
# 77.0    77.0      1534
# 28.0    28.0      1493
# 4.0     4.0       1434
#                   ...
# 200.0   200.0      849
# 68.0    68.0       837
# 69.0    69.0       832
# 3.0     3.0        827
# 85.0    85.0       792
# 62.0    62.0       788
# 59.0    59.0       786
# 64.0    64.0       771
# ...

# %% [markdown]
# c. Create a clustering model that clusters cardholders based on the frequency of credit card usage and spend and number of unique merchants. Identify/Name the clusters and provide relevant metrics that reflect the quality of the clustering.

# %%
testnew = test[['amount','merchant category code (mcc)', 'vendor','cardholder first initial','cardholder last name']].copy()

# %%
testnew["cardholdername"] = testnew["cardholder last name"] + testnew['cardholder first initial']

# %%
testnew.groupby(['cardholdername'])['merchant category code (mcc)'].nunique()
# Out:
# cardholdername
# 241002                     1
# 420004                     1
# 446004                     1
# 480004                     1
# 530005                     1
# 531005                     1
# 750007                     1
# 770007                     1
# 815008                     1
# 880008                     1
# 980009                     1
# AARONB                     1
# ACREET                    11
# ADAMSC                     5
# ADAMSK                    16
# ADAMSS                     6
# ADED                       7
# ADMIREA                    5
# ADUDDELLD                  3
# AGNELLIM                   8
# AKBARANB                   1
# ALEXANDERD                10
# ALFORDR                    8
# ALINGERD                  15
# ALL ABOUT TRAVEL LTD.G     5
# ALL ABOUT TRAVELG         13
# ALLEE-FOREMANK             9
# ALLENC                    15
# ALLENS                    28
# ALLENT                     5
#                           ..
# ...

# %%
#drop the rows with invalid names
testnew = testnew[testnew.cardholdername.apply(lambda x: x.isalpha())]

# %%
testnew.shape
# Out:
# (255586, 6)

# %%
testnew.groupby(['cardholdername'])['amount'].sum()
# Out:
# cardholdername
# AARONB               235.0
# ACREET             16527.0
# ADAMSC               875.0
# ADAMSK              7130.0
# ADAMSS              2351.0
# ADED                4811.0
# ADMIREA             3864.0
# ADUDDELLD           2725.0
# AGNELLIM           17259.0
# AKBARANB             400.0
# ALEXANDERD          4206.0
# ALFORDR            19758.0
# ALINGERD            4990.0
# ALLENC             10117.0
# ALLENS             69166.0
# ALLENT               487.0
# ALLREADJ            9529.0
# ALLSJ              58684.0
# ANDERSONB          10393.0
# ANDERSONG           3005.0
# ANDERSONR           8874.0
# ANDESK             27193.0
# ANGELOTTIL            70.0
# ANP                 4880.0
# ARBESD             10657.0
# ARCAROLIP           6111.0
# ARDENC            100533.0
# ARGOJ               1491.0
# ARMSTRONGG            72.0
# ARMSTRONGS          3727.0
#                     ...
# YoungD             11763.0
# YoungG              4837.0
# YoungJ             33389.0
# ...

# %%
testnew.groupby(['cardholdername'])['amount'].nunique()
# Out:
# cardholdername
# AARONB              1
# ACREET             57
# ADAMSC             13
# ADAMSK             31
# ADAMSS             19
# ADED               22
# ADMIREA            45
# ADUDDELLD           5
# AGNELLIM           32
# AKBARANB            1
# ALEXANDERD         13
# ALFORDR            37
# ALINGERD           39
# ALLENC             47
# ALLENS            171
# ALLENT              8
# ALLREADJ           19
# ALLSJ             134
# ANDERSONB          56
# ANDERSONG          22
# ANDERSONR          48
# ANDESK             74
# ANGELOTTIL          1
# ANP                 5
# ARBESD             46
# ARCAROLIP          25
# ARDENC            185
# ARGOJ               8
# ARMSTRONGG          3
# ARMSTRONGS         35
#                  ...
# YoungD             18
# YoungG              2
# YoungJ             65
# YoungN             62
# YoussefN           41
# YuanS              15
# ZACCARELLIC        83
# ZEDEKERT           19
# ZHANGG              1
# ZHANGX              9
# ...

# %%
percentile_list = pd.DataFrame(
    {'mccunique': testnew.groupby(['cardholdername'])['merchant category code (mcc)'].nunique(),
     'amount': testnew.groupby(['cardholdername'])['amount'].nunique(),
     'amountfreq': testnew.groupby(['cardholdername'])['amount'].sum()
    })

percentile_list.shape
# Out:
# (4675, 3)

# %%
x = percentile_list.ix[:,:]
s_s = StandardScaler().fit_transform(x)
tsne = TSNE(n_components=2,random_state=0)
x_tt = tsne.fit_transform(s_s)

# %%
#Initially I am taking 5 classes
markers = ('s','d','o','1','2')
color_map = {0:'red',1:'blue',2:'lightblue',3:'green',4:'cyan'}
plt.figure()
for idx,cl in enumerate(np.unique(x_tt)):
    while idx >= 5:
        idx = idx%5
    plt.scatter(x = x_tt[int(cl),0],y = x_tt[int(cl),1],c=color_map[idx],marker=markers[idx],label=int(cl))

# %%
plt.scatter(s_s[:,1],s_s[:,0])

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(s_s[:,0],s_s[:,1],s_s[:,2],marker='o',c=color_map[3])
ax.set_xlabel("unique merchants")
ax.set_ylabel("Frequency")
ax.set_zlabel("Amount")
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(s_s)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
fig = plt.figure()
ax = fig.add_subplot(111,projection = '3d')
for x in range(len(s_s)):
    ax.scatter(s_s[x][0],s_s[x][1],s_s[x][2],c=color_map[labels[x]])
#for me I would have used some 5 or 6 clusters lets see how could we find the optimal solution

# %%
c_range = range( 1, 30 )
error = []
for num_clusters in c_range:
  clusters = KMeans( num_clusters )
  clusters.fit( s_s )
  error.append( clusters.inertia_ )

# %%
test = pd.DataFrame(c_range,error)

# %%
plt.plot(c_range,error)
